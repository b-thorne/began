# %%
import h5py
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_hdf("../models/plots/metrics.h5", "spectra")
df
# Out:
#          bandpowers  multipoles  batch_number
# 0      7.550651e-04        36.0             0
# 1     -1.996696e-05       108.0             0
# 2      3.827114e-07       180.0             0
# 3      2.421410e-08       252.0             0
# 4      2.170441e-08       324.0             0
# ...             ...         ...           ...
# 56091  1.021188e-10      1980.0          1752
# 56092  7.481684e-11      2052.0          1752
# 56093  6.214099e-11      2124.0          1752
# 56094  4.462553e-11      2196.0          1752
# 56095  4.239189e-11      2268.0          1752
#
# [56096 rows x 3 columns]

# %%
df_planck = df.sample(frac=0.5)
df_vae = df.sample(frac=0.5)

# %%
sns.set(rc={'figure.figsize': (11, 8), 'figure.dpi': 300, 'font.size': 30, 'text.usetex': False})
ax = sns.lineplot(x="multipoles", y="bandpowers", data=df.sample(frac=0.5), label='Planck')
ax = sns.lineplot(x="multipoles", y="bandpowers", data=df.sample(frac=0.5), label='VAE')
ax.set(yscale='log', xscale='log', ylim=[1e-8, 4e-5], xlim=[400, 2000])
ax.set(ylabel=r"$C_\ell^{\rm TT}~{\rm [arb~units]}$")
ax.set(xlabel=r"$\ell_b$")
ax.set(title="VAE power spectrum comparison")
fig = ax.get_figure()
fig.savefig("../reports/figures/cl_band_power.png", bbox_inches='tight')

# %%
ax = sns.distplot(np.log10(df[df.multipoles.eq(324.)].bandpowers))

# %%
ax = sns.distplot(np.log10(df[df.multipoles.eq(324.)].bandpowers))

# %%
df.multipoles.eq(36.)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 58843    False
# 58844    False
# 58845    False
# 58846    False
# 58847    False
# Name: multipoles, Length: 58848, dtype: bool

# %%
ax = sns.lineplot(x="multipoles", y="bandpowers", data=df[df.batch_number.eq(0)])
ax.set(yscale='log')
# Out:
# [None]

# %%
import pymaster as nmt

# %%
npix_x = 256
ang_x = 20
ang_y = 20
l0_bins = np.arange(npix_x / 8.) * 8 * np.pi / ang_x
lf_bins = (np.arange(npix_x / 8.) + 1.) * 8. * np.pi / ang_y

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]
